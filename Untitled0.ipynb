# %% [markdown]
# <a href="https://colab.research.google.com/github/anciyajaison/ict_assignments/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (1,101):
  if i % 3 == 0 :
    print('Fizz')
  elif i % 3 == 0:
    print('buzz')
  elif i % 5 == 0:
    print('fizzBuzz')
  else:
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# fizzBuzz
# Fizz
# 7
# 8
# Fizz
# fizzBuzz
# 11
# Fizz
# 13
# 14
# Fizz
# 16
# 17
# Fizz
# 19
# fizzBuzz
# Fizz
# 22
# 23
# Fizz
# fizzBuzz
# 26
# Fizz
# 28
# 29
# Fizz
# 31
# 32
# Fizz
# 34
# fizzBuzz
# Fizz
# 37
# 38
# Fizz
# fizzBuzz
# 41
# Fizz
# 43
# 44
# Fizz
# 46
# 47
# Fizz
# 49
# fizzBuzz
# Fizz
# 52
# 53
# Fizz
# fizzBuzz
# 56
# Fizz
# 58
# 59
# Fizz
# 61
# 62
# Fizz
# 64
# fizzBuzz
# Fizz
# 67
# 68
# Fizz
# fizzBuzz
# 71
# Fizz
# 73
# 74
# Fizz
# 76
# 77
# Fizz
# 79
# fizzBuzz
# Fizz
# 82
# 83
# Fizz
# fizzBuzz
# 86
# Fizz
# 88
# 89
# Fizz
# 91
# 92
# Fizz
# 94
# fizzBuzz
# Fizz
# 97
# 98
# Fizz
# fizzBuzz

# %%
a =int(input('number of unit consumed'))
if a<=100:
  bill = a*5
  print('total bill amount:',bill)
elif a<=200:
  bill = (100*5)+((a-100)*7)
  print('total bill amount:',bill)
else:
  bill = (100*5)+(100*7)+((a-200)*10)
  print('total bill amount:',bill)
# Out:
# number of unit consumed245
# total bill amount: 1650

# %%
a=['*','**','***','****','*****']
for i in a:
  print(i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
a =input('enter a num of string:')
if a==a[::-1]:
 print('the givennum or string is palindrome')
else:
 print('the givennum or string is not palindrome')
# Out:
# enter a num of string:121
# the givennum or string is palindrome
